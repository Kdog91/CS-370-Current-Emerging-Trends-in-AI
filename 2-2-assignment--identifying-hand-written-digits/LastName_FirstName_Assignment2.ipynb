# %% [markdown]
# # CS 370 Module Two Assignment
# ---
# <div class="alert alert-block alert-success" style="color:black;">
# <b>To Begin:</b> Use this <b>LastName_FirstName_Assignment2.ipynb</b> file to complete your assignment. Look for the section header <b>Start of Rubric Graded Items</b> for the placeholders for your assignment.
# <br><br>
# <b>When Finished:</b> When you have completed your work, download the project as an HTML file and submit the HTML file. Make sure that your file is named as specified in the rubric, and that you have addressed all of the rubric criteria in your response.
# </div>
#
# <div class="alert alert-block alert-info" style="color:black;">
#     <b>Hint:</b> The code samples from the <b>Deep Learning with Keras</b> required readings pages 16-21 have been pre-loaded for you in the <b>Example_Code_Assignment2.ipynb</b> file. Some of the foundational starter code has also been added here as a starting point for your assignment as applicable.
# </div>
#
# <div class="alert alert-block alert-warning" style="color:black;">
#     <b>Note:</b> For compatability purposes, libraries have been updated from those used in the required readings to match to current versions; hence some of the package invocations may differ slightly from the book. The affected lines of code have comments added to the right as applicable, with the old code commented out above for reference.
# </div>
#
# <div class="alert alert-block alert-danger" style="color:black;">
# <b>GPU/CUDA/Memory Warnings/Errors:</b> You may receive some errors referencing that GPUs will not be used, CUDA could not be found, or free system memory allocation errors. These and a few others, are standard errors that can be ignored here as they are environment based.<br><br>
# <b>Example messages:</b>
#     <ul>
#         <li>Could not find cuda drivers on your machine, GPU will not be used.</li>
#         <li>Please check linkage and avoid linking the same target more than once.</li>
#         <li>E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)</li>
#         <li>Allocation of ######## exceeds 10% of free system memory</li>
#     </ul>
# </div>
#
# ---
#
# ## Required Baseline Starter Code
# ---
#
# ### Installing Required Packages
# This is to install necessary components to run the assignment
# <div class="alert alert-block alert-info" style="color:black;">
#     <b>Hint:</b> Ensure that you run all starter code blocks before running your code from the <b>Start of Rubric Graded Items</b> sections.
# </div>

# %%
# !pip install -r requirements.txt
# Out:
# Collecting numpy==1.26 (from -r requirements.txt (line 1))
#   Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 761.1 kB/s eta 0:00:00a 0:00:01
# Collecting keras==3.10.0 (from -r requirements.txt (line 2))
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: absl-py in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: rich in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (13.7.1)
# Requirement already satisfied: namex in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (0.0.8)
# Requirement already satisfied: h5py in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (3.11.0)
# Requirement already satisfied: optree in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: ml-dtypes in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: packaging in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from optree->keras==3.10.0->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras==3.10.0->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras==3.10.0->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras==3.10.0->-r requirements.txt (line 2)) (0.1.2)
# Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 39.0 MB/s eta 0:00:00:00:0100:01
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.8 MB/s eta 0:00:00:00:01
# Installing collected packages: numpy, keras
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# Successfully installed keras-3.10.0 numpy-1.26.0
#
# [notice] A new release of pip is available: 24.1.2 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ---
# ### Loading the Required Libraries
# <div class="alert alert-block alert-danger" style="color:black;">
# <b>Warnings:</b> As a reminder, you may receive some errors here, these are standard errors that can be ignored as they are environment based.
# </div>
#
# Potentially helpful links:
# - https://keras.io/
# - https://keras.io/api/datasets/
# - https://keras.io/api/models/
# - https://keras.io/api/layers/
# - https://keras.io/api/optimizers/
# - https://keras.io/api/utils/python_utils/

# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
#from keras.layers.code import Dense, Activation # From the book, code replaced below
from keras.layers import Dense, Activation, Input # syntax change due to version bump
from keras.optimizers import SGD
#from keras.utils import np_utils # From the book, code replaced below
from keras.utils import to_categorical # syntax change due to version bump

# %% [markdown]
# ---
# ### Generating a Numpy Random Seed For Reproducibility
# <div class="alert alert-block alert-warning" style="color:black;">
#     <b>Note:</b> The best practice is to not reseed a BitGenerator, but rather to recreate a new one. While this method for the the seed generation is considered a legacy function, here we use it to as a way to ensure reproducible results for repeatble course submissions.
# </div>
#
# Potentially helpful links:
# - https://keras.io/api/utils/python_utils/

# %%
np.random.seed(1671) # for reproducibility

# %% [markdown]
# ---
# ### Network and Training Parameters
# <div class="alert alert-block alert-danger" style="color:black;">
# <b>Warnings:</b> As a reminder, you may receive some errors here, these are standard errors that can be ignored as they are environment based.
# </div>

# %%
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() # SGD optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 # how much TRAIN is reserved for VALIDATION
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778933887.845114     363 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1778933887.909175     363 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1778933887.910868     363 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1778933887.917142     363 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1778933887.918731     363 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1778933887.920273     363 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1778933888.135895     363 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1778933888.137647     363 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1778933888.139213     363 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ---
# ### Spliting Data Into Train and Test Sets

# %%
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# ---
# ### Shaping

# %%
# X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize
X_train /= 255
X_test /= 255

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices

# Y_train = np_utils.to_categorical(y_train, NB_CLASSES) # From the book, code replaced below
Y_train = to_categorical(y_train, NB_CLASSES) # Updated for current version

#Y_test = np_utils.to_categorical(y_test, NB_CLASSES) # From the book, code replaced below
Y_test = to_categorical(y_test, NB_CLASSES) # Updated for current version

# %% [markdown]
# ---
# # Start of Rubric Graded Items
# ---
# <div class="alert alert-block alert-success" style="color:black;">
# <b>To Begin:</b> Once you have reviewed the output of the blocks above, use the blocks below to complete your assignment portions.
# </div>
#
# <div class="alert alert-block alert-info" style="color:black;">
#     <b>Hint:</b> As a reminder, the code samples from the <b>Deep Learning with Keras</b> required readings pages 16-21 have been pre-loaded for you in the <b>Example_Code_Assignment2.ipynb</b> file. Some of the foundational starter code has also been added here as a starting point for your assignment as applicable in the cells above.
# </div>
#
# ---
#
# ## Notebook Configuration and Naming Convention
# Click on LastName_FirstName_Assignment2.ipynb in the filetree and rename it following that convention. For example, if your name is Jane Doe, you would rename the file Doe_Jane_Assignment2.ipynb for later submission.
#
# ---
# ## Establishes Accuracy Scores with Two Hidden Layers
# Follow the examples in the book to establish an accuracy rate for the training, validation, and test data sets with two hidden layers.
#
#
# <div class="alert alert-block alert-warning" style="color:black;">
#     <b>Note:</b> The example model configurations provided below must be modified for your assignment submission. Some lines are standard commands.
# </div>
#
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> Read through the MNIST handwritten digits example on pages 16-24 of <b>Deep Learning with Keras</b>. The code from pages 16-18 have been copied over to this Jupyter Notebook file for you as applicable in the cells above above for the minimum required baseline code. The hidden layers examples are provided starting on page 22, ensure to keep example modifications from above in mind when building out the rest of your assignment code blocks. The code below can be copied and used to start building out your hidden layers task.
# <br><br>
# <div style="background:#eff0f1;padding-left:10px">
# <code style="margin-left:-5px"><b>Book Example Code Snippet: A simple neural net in Keras</b>
# # 10 outputs
# # final stage is softmax
# model = Sequential()
# # model.add(Dense(NB_CLASSES, input_shape=(RESHAPED,))) # From the book, code replaced below
# model.add(Input(shape=(RESHAPED,))) # Updated for current version
# model.add(Dense(NB_CLASSES)) # Updated for current version
# model.add(Activation('softmax'))
# model.summary()
# model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])
# history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE,
# validation_split=VALIDATION_SPLIT)
# score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
# print("Test Score:", score[0])
# print("Test Accuracy:", score[1])
# </code>
# </div>
# </div>
#
# <div class="alert alert-block alert-danger" style="color:black;">
# <b>Warnings:</b> As a reminder, you may receive some errors in the model here, these are standard errors that can be ignored as they are environment based.
# </div>
#
# Potentially helpful links:
# - https://keras.io/api/models/sequential/
# - https://keras.io/api/layers/activations/
# - https://keras.io/api/models/sequential/#add-method
# - https://keras.io/api/layers/
# - https://keras.io/api/layers/core_layers/
# - https://keras.io/api/models/model_training_apis/#compile-method
# - https://keras.io/api/models/model_training_apis/#fit-method
# - https://keras.io/api/models/model_training_apis/#evaluate-method

# %% [markdown]
# ---
# ## Establishes Accuracy Scores by Varying Parameters
# Pick one parameter and run two or three different experiments modifying the parameter values to establish accuracy scores with different parameter values. Make sure the experiments result in significant changes in accuracy rates. Be sure to place each experiment in a different code block so that your instructor can view all of your changes.
#
# <div class="alert alert-block alert-warning" style="color:black;">
#     <b>Note:</b> You may have to do some research beyond the information provided in the book to implement these changes. Remember to copy your model definition, compilation, training, and evaluation blocks to test your experiment.
# </div>
#
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> Sample parameters that you can overwrite here were used in the <b>Network and Training Parameters</b> section above. This is not all inclusive and just provided as a baseline. See the additional example parameters starting on page 25 in the <b>Deep Learning with Keras</b> book.
# <br><br><b>Important:</b> When codifying your experiements, ensure that you include the replacement variable in the cell below, followed by the hidden layers code you developed in the rubric item above.<br><br>
# <div style="background:#eff0f1;padding-left:10px">
# <code style="margin-left:-5px"><b>Book Example Code Snippet: Copied from cell above for quick reference to variable naming</b>
# NB_EPOCH = 20
# BATCH_SIZE = 128
# VERBOSE = 1
# NB_CLASSES = 10 # number of outputs = number of digits
# OPTIMIZER = SGD() # SGD optimizer, explained later in this chapter
# N_HIDDEN = 128
# VALIDATION_SPLIT = 0.2 # how much TRAIN is reserved for VALIDATION
# </code>
# </div>
# </div>
#
# Potentially helpful links:
# - https://keras.io/api/models/model_training_apis/#fit-method
#
# ### Experiment 1
#
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> When modifying parameters that will impact the optimization of the solution, ensure that you add the <b>OPTIMIZER = SGD()</b> line before your code with the hidden layers from above.
# </div>

# %%
# Experiment 1: NB_EPOCH = 5 (reduced epochs)
NB_EPOCH = 5
OPTIMIZER = SGD()

model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)

score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print("Test accuracy:", score[1])
# Out:
# /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778934436.742622     470 service.cc:146] XLA service 0x76ad48017860 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778934436.742653     470 service.cc:154]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
#  92/375 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1075 - loss: 396.0706
# I0000 00:00:1778934437.618157     470 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.1116 - loss: 135.0728 - val_accuracy: 0.1061 - val_loss: 2.3027
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1130 - loss: 2.3012 - val_accuracy: 0.1061 - val_loss: 2.3026
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1134 - loss: 2.3012 - val_accuracy: 0.1061 - val_loss: 2.3026
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1151 - loss: 2.3010 - val_accuracy: 0.1061 - val_loss: 2.3027
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1135 - loss: 2.3010 - val_accuracy: 0.1061 - val_loss: 2.3027
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1160 - loss: 2.3187
# Test score: 2.314631462097168
# Test accuracy: 0.11349999904632568

# %% [markdown]
# ### Experiment 2
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> When modifying parameters that will impact the optimization of the solution, ensure that you add the <b>OPTIMIXER = SGD()</b> line before your code with the hidden layers from above.
# </div>

# %%
# Experiment 2: NB_EPOCH = 50 (increased epochs)
NB_EPOCH = 50
OPTIMIZER = SGD()

model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)

score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print("Test accuracy:", score[1])
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1081 - loss: 61203.4531 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1129 - loss: 2.3016 - val_accuracy: 0.1060 - val_loss: 2.3026
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1151 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 2.3026
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1126 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 2.3026
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1133 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 2.3027
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1152 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3027
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1125 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 2.3027
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1137 - loss: 2.3013 - val_accuracy: 0.1060 - val_loss: 2.3027
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1163 - loss: 2.3007 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1141 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1128 - loss: 2.3010 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1147 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1131 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1150 - loss: 2.3006 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1150 - loss: 2.3006 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1165 - loss: 2.3007 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1128 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1118 - loss: 2.3013 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1139 - loss: 2.3010 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1144 - loss: 2.3010 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1139 - loss: 2.3009 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1129 - loss: 2.3010 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1103 - loss: 2.3015 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1138 - loss: 2.3010 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1142 - loss: 2.3009 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1161 - loss: 2.3007 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1120 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1157 - loss: 2.3005 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1125 - loss: 2.3015 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1158 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1155 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1123 - loss: 2.3009 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1153 - loss: 2.3009 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1136 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1136 - loss: 2.3009 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1130 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1132 - loss: 2.3009 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1143 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1144 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1118 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1133 - loss: 2.3009 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1136 - loss: 2.3009 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1153 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1128 - loss: 2.3014 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1147 - loss: 2.3010 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1149 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1136 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1104 - loss: 2.3016 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1126 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 2.3028
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1157 - loss: 2.3005 - val_accuracy: 0.1060 - val_loss: 2.3028
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1159 - loss: 3.4653
# Test score: 2.6031007766723633
# Test accuracy: 0.11339999735355377

# %% [markdown]
# ### Experiment 3 (Optional)
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> When modifying parameters that will impact the optimization of the solution, ensure that you add the <b>OPTIMIZER = SGD()</b> line before your code with the hidden layers from above.
# </div>

# %%
# Experiment 3: Switching optimizer from SGD to Adam
NB_EPOCH = 20
OPTIMIZER = SGD()

model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)

score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print("Test accuracy:", score[1])
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1091 - loss: 1810206720.0000 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1141 - loss: 2.3015 - val_accuracy: 0.1060 - val_loss: 6.6071
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1140 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 6.6070
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1142 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 6.6071
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1114 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 6.6071
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1123 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 6.6071
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1131 - loss: 2.3013 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1127 - loss: 2.3013 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1142 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1139 - loss: 2.3010 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1144 - loss: 2.3007 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1152 - loss: 2.3006 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1136 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1140 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1122 - loss: 2.3015 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1142 - loss: 2.3011 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1128 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1124 - loss: 2.3012 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1158 - loss: 2.3007 - val_accuracy: 0.1060 - val_loss: 6.6072
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1152 - loss: 2.3007 - val_accuracy: 0.1060 - val_loss: 6.6072
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1160 - loss: 2.3009
# Test score: 2.3010032176971436
# Test accuracy: 0.11349999904632568

# %% [markdown]
# ---
# ## Explains Changes in Accuracy Rates
# Create a Markdown cell in your Jupyter Notebook after your code and its outputs.
# In this cell, explain the changes in accuracy rates by comparing and contrasting your results from Steps 3 and 4. What happens to the accuracy rates for the training, validation, and test data sets as you change the parameters. Why?
#
# <div class="alert alert-block alert-info" style="color:black;">
#     <b>Hint:</b> To use the markdown block below, double click in the <b>Type Markdown and LaTeX:  𝛼2</b> block below, to turn it back to html, Run the cell.
# </div>
#
# Potentially helpful links:
# - https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html
